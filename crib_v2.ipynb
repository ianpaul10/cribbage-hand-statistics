# %%
import math
import statistics
import random
import utils
from itertools import combinations

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# %load_ext memray

# %%
_pretty_suits = ["♥", "♦", "♠", "♣"]
_boring_suits = ["H", "D", "S", "C"]

_values = list(range(2, 10))
_values.extend(["T", "J", "Q", "K", "A"])

pretty_deck = []
deck = []
for i in range(len(_pretty_suits)):
    for value in _values:
        pretty_deck.append(f"{value}{_pretty_suits[i]}")
        deck.append(f"{value}{_boring_suits[i]}")

# %%
print(len(deck))
print(deck[0:14])
# Out:
# 52
# ['2H', '3H', '4H', '5H', '6H', '7H', '8H', '9H', 'TH', 'JH', 'QH', 'KH', 'AH', '2D']

# %%
starting_hand_size = 6
hand_size = 4

# %%
# 52c4 * 48
# where 48 is the remaining cards after you get your hand
unique_hands = math.comb(len(deck), hand_size) * (len(deck) - hand_size)
print(f"{unique_hands=:,}")

# 6 cards dealt to you, you have to discard 2
unique_hands_dealt = math.comb(len(deck), starting_hand_size)
print(f"{unique_hands_dealt=:,}")

# from the 6 dealt, you could discard any 2 of them
unique_sub_hands = math.comb(starting_hand_size, hand_size)
print(f"{unique_sub_hands=:,}")

# this means you can have any combination of 52c6 * 6c2 number of hands
total_possible_hands = unique_hands_dealt * unique_sub_hands
print(f"{total_possible_hands=:,}")

# crib will be made up of (52-6)c2 * 2 of your 6 cards (or 6c2)
possible_crib_hands = math.comb(len(deck) - starting_hand_size, 2) * unique_sub_hands
print(f"{possible_crib_hands=:,}")
# Out:
# unique_hands=12,994,800
# unique_hands_dealt=20,358,520
# unique_sub_hands=15
# total_possible_hands=305,377,800
# possible_crib_hands=15,525

# %%
# set of all possible 6 card starting hands
starting_hand_list = list(combinations(deck, r=starting_hand_size))
# proof of no duplicates for peace of mind
starting_hand_set = frozenset(starting_hand_list)

# %%
print(f"{len(starting_hand_list)=:,}")
print(f"{starting_hand_list[:10]}")
# Out:
# len(starting_hand_list)=20,358,520
# [('2H', '3H', '4H', '5H', '6H', '7H'), ('2H', '3H', '4H', '5H', '6H', '8H'), ('2H', '3H', '4H', '5H', '6H', '9H'), ('2H', '3H', '4H', '5H', '6H', 'TH'), ('2H', '3H', '4H', '5H', '6H', 'JH'), ('2H', '3H', '4H', '5H', '6H', 'QH'), ('2H', '3H', '4H', '5H', '6H', 'KH'), ('2H', '3H', '4H', '5H', '6H', 'AH'), ('2H', '3H', '4H', '5H', '6H', '2D'), ('2H', '3H', '4H', '5H', '6H', '3D')]

# %%
starting_hands_with_possible_sub_hands = {
    element: list(combinations(element, r=hand_size)) for element in starting_hand_list
}

# %%
starting_hands_with_possible_sub_hands[("2H", "3H", "4H", "5H", "6H", "7H")])
# Out:
# [('2H', '3H', '4H', '5H'),
#  ('2H', '3H', '4H', '6H'),
#  ('2H', '3H', '4H', '7H'),
#  ('2H', '3H', '5H', '6H'),
#  ('2H', '3H', '5H', '7H'),
#  ('2H', '3H', '6H', '7H'),
#  ('2H', '4H', '5H', '6H'),
#  ('2H', '4H', '5H', '7H'),
#  ('2H', '4H', '6H', '7H'),
#  ('2H', '5H', '6H', '7H'),
#  ('3H', '4H', '5H', '6H'),
#  ('3H', '4H', '5H', '7H'),
#  ('3H', '4H', '6H', '7H'),
#  ('3H', '5H', '6H', '7H'),
#  ('4H', '5H', '6H', '7H')]

# %%
df_starting_hands = pd.DataFrame(
    starting_hands_with_possible_sub_hands.items(),
    columns=["starting_hand", "sub_hands"],
)

# %%
df_starting_hands.head()
# Out:
#               starting_hand                                          sub_hands
# 0  (2H, 3H, 4H, 5H, 6H, 7H)  [(2H, 3H, 4H, 5H), (2H, 3H, 4H, 6H), (2H, 3H, ...
# 1  (2H, 3H, 4H, 5H, 6H, 8H)  [(2H, 3H, 4H, 5H), (2H, 3H, 4H, 6H), (2H, 3H, ...
# 2  (2H, 3H, 4H, 5H, 6H, 9H)  [(2H, 3H, 4H, 5H), (2H, 3H, 4H, 6H), (2H, 3H, ...
# 3  (2H, 3H, 4H, 5H, 6H, TH)  [(2H, 3H, 4H, 5H), (2H, 3H, 4H, 6H), (2H, 3H, ...
# 4  (2H, 3H, 4H, 5H, 6H, JH)  [(2H, 3H, 4H, 5H), (2H, 3H, 4H, 6H), (2H, 3H, ...

# %%
df_starting_hands["starting_hand_str"] = df_starting_hands.apply(
    lambda row: ",".join(str(x) for x in row["starting_hand"]), axis=1
)

df_starting_hands.head()
# Out:
#               starting_hand  \
# 0  (2H, 3H, 4H, 5H, 6H, 7H)
# 1  (2H, 3H, 4H, 5H, 6H, 8H)
# 2  (2H, 3H, 4H, 5H, 6H, 9H)
# 3  (2H, 3H, 4H, 5H, 6H, TH)
# 4  (2H, 3H, 4H, 5H, 6H, JH)
#
#                                            sub_hands  starting_hand_str
# 0  [(2H, 3H, 4H, 5H), (2H, 3H, 4H, 6H), (2H, 3H, ...  2H,3H,4H,5H,6H,7H
# 1  [(2H, 3H, 4H, 5H), (2H, 3H, 4H, 6H), (2H, 3H, ...  2H,3H,4H,5H,6H,8H
# 2  [(2H, 3H, 4H, 5H), (2H, 3H, 4H, 6H), (2H, 3H, ...  2H,3H,4H,5H,6H,9H
# 3  [(2H, 3H, 4H, 5H), (2H, 3H, 4H, 6H), (2H, 3H, ...  2H,3H,4H,5H,6H,TH
# 4  [(2H, 3H, 4H, 5H), (2H, 3H, 4H, 6H), (2H, 3H, ...  2H,3H,4H,5H,6H,JH

# %%
# df2[['team1','team2']] = pd.DataFrame(df2.teams.tolist(), index= df2.index)
sub_hands_col_names = [f"sub_hands_str_{i}" for i in range(unique_sub_hands)]

df_starting_hands[sub_hands_col_names] = pd.DataFrame(
    df_starting_hands.sub_hands.tolist(), index=df_starting_hands.index
)

# %%
df_starting_hands.head()
# Out:
#               starting_hand  \
# 0  (2H, 3H, 4H, 5H, 6H, 7H)
# 1  (2H, 3H, 4H, 5H, 6H, 8H)
# 2  (2H, 3H, 4H, 5H, 6H, 9H)
# 3  (2H, 3H, 4H, 5H, 6H, TH)
# 4  (2H, 3H, 4H, 5H, 6H, JH)
#
#                                            sub_hands  starting_hand_str  \
# 0  [(2H, 3H, 4H, 5H), (2H, 3H, 4H, 6H), (2H, 3H, ...  2H,3H,4H,5H,6H,7H
# 1  [(2H, 3H, 4H, 5H), (2H, 3H, 4H, 6H), (2H, 3H, ...  2H,3H,4H,5H,6H,8H
# 2  [(2H, 3H, 4H, 5H), (2H, 3H, 4H, 6H), (2H, 3H, ...  2H,3H,4H,5H,6H,9H
# 3  [(2H, 3H, 4H, 5H), (2H, 3H, 4H, 6H), (2H, 3H, ...  2H,3H,4H,5H,6H,TH
# 4  [(2H, 3H, 4H, 5H), (2H, 3H, 4H, 6H), (2H, 3H, ...  2H,3H,4H,5H,6H,JH
#
#     sub_hands_str_0   sub_hands_str_1   sub_hands_str_2   sub_hands_str_3  \
# 0  (2H, 3H, 4H, 5H)  (2H, 3H, 4H, 6H)  (2H, 3H, 4H, 7H)  (2H, 3H, 5H, 6H)
# 1  (2H, 3H, 4H, 5H)  (2H, 3H, 4H, 6H)  (2H, 3H, 4H, 8H)  (2H, 3H, 5H, 6H)
# 2  (2H, 3H, 4H, 5H)  (2H, 3H, 4H, 6H)  (2H, 3H, 4H, 9H)  (2H, 3H, 5H, 6H)
# 3  (2H, 3H, 4H, 5H)  (2H, 3H, 4H, 6H)  (2H, 3H, 4H, TH)  (2H, 3H, 5H, 6H)
# 4  (2H, 3H, 4H, 5H)  (2H, 3H, 4H, 6H)  (2H, 3H, 4H, JH)  (2H, 3H, 5H, 6H)
#
#     sub_hands_str_4   sub_hands_str_5   sub_hands_str_6   sub_hands_str_7  \
# 0  (2H, 3H, 5H, 7H)  (2H, 3H, 6H, 7H)  (2H, 4H, 5H, 6H)  (2H, 4H, 5H, 7H)
# 1  (2H, 3H, 5H, 8H)  (2H, 3H, 6H, 8H)  (2H, 4H, 5H, 6H)  (2H, 4H, 5H, 8H)
# 2  (2H, 3H, 5H, 9H)  (2H, 3H, 6H, 9H)  (2H, 4H, 5H, 6H)  (2H, 4H, 5H, 9H)
# 3  (2H, 3H, 5H, TH)  (2H, 3H, 6H, TH)  (2H, 4H, 5H, 6H)  (2H, 4H, 5H, TH)
# 4  (2H, 3H, 5H, JH)  (2H, 3H, 6H, JH)  (2H, 4H, 5H, 6H)  (2H, 4H, 5H, JH)
#
#     sub_hands_str_8   sub_hands_str_9  sub_hands_str_10  sub_hands_str_11  \
# 0  (2H, 4H, 6H, 7H)  (2H, 5H, 6H, 7H)  (3H, 4H, 5H, 6H)  (3H, 4H, 5H, 7H)
# 1  (2H, 4H, 6H, 8H)  (2H, 5H, 6H, 8H)  (3H, 4H, 5H, 6H)  (3H, 4H, 5H, 8H)
# 2  (2H, 4H, 6H, 9H)  (2H, 5H, 6H, 9H)  (3H, 4H, 5H, 6H)  (3H, 4H, 5H, 9H)
# 3  (2H, 4H, 6H, TH)  (2H, 5H, 6H, TH)  (3H, 4H, 5H, 6H)  (3H, 4H, 5H, TH)
# 4  (2H, 4H, 6H, JH)  (2H, 5H, 6H, JH)  (3H, 4H, 5H, 6H)  (3H, 4H, 5H, JH)
#
#    sub_hands_str_12  sub_hands_str_13  sub_hands_str_14
# 0  (3H, 4H, 6H, 7H)  (3H, 5H, 6H, 7H)  (4H, 5H, 6H, 7H)
# 1  (3H, 4H, 6H, 8H)  (3H, 5H, 6H, 8H)  (4H, 5H, 6H, 8H)
# 2  (3H, 4H, 6H, 9H)  (3H, 5H, 6H, 9H)  (4H, 5H, 6H, 9H)
# 3  (3H, 4H, 6H, TH)  (3H, 5H, 6H, TH)  (4H, 5H, 6H, TH)
# 4  (3H, 4H, 6H, JH)  (3H, 5H, 6H, JH)  (4H, 5H, 6H, JH)

# %%
points_df = pd.read_csv("crib_hands.csv")

# making columns easier to work with
points_df["hand"] = (
    points_df["hand_card_1"]
    + ","
    + points_df["hand_card_2"]
    + ","
    + points_df["hand_card_3"]
    + ","
    + points_df["hand_card_4"]
    + ","
    + points_df["cut_card"]
)
points_df = points_df.drop(
    columns=["hand_card_1", "hand_card_2", "hand_card_3", "hand_card_4", "cut_card"]
)

points_df.set_index("hand", inplace=True)

points_dict = points_df.T.to_dict(
    orient="list",
)

# %%
points_dict
# Out:
# {'2H,3H,4H,5H,6H': [14],
#  '2H,3H,4H,5H,7H': [11],
#  '2H,3H,4H,5H,8H': [13],
#  '2H,3H,4H,5H,9H': [11],
#  '2H,3H,4H,5H,TH': [13],
#  '2H,3H,4H,5H,JH': [13],
#  '2H,3H,4H,5H,QH': [13],
#  '2H,3H,4H,5H,KH': [13],
#  '2H,3H,4H,5H,AH': [12],
#  '2H,3H,4H,5H,2D': [14],
#  '2H,3H,4H,5H,3D': [16],
#  '2H,3H,4H,5H,4D': [16],
#  '2H,3H,4H,5H,5D': [16],
#  '2H,3H,4H,5H,6D': [13],
#  '2H,3H,4H,5H,7D': [10],
#  '2H,3H,4H,5H,8D': [12],
#  '2H,3H,4H,5H,9D': [10],
#  '2H,3H,4H,5H,TD': [12],
#  '2H,3H,4H,5H,JD': [12],
#  '2H,3H,4H,5H,QD': [12],
#  '2H,3H,4H,5H,KD': [12],
#  '2H,3H,4H,5H,AD': [7],
#  '2H,3H,4H,5H,2S': [14],
#  '2H,3H,4H,5H,3S': [16],
#  '2H,3H,4H,5H,4S': [16],
#  '2H,3H,4H,5H,5S': [16],
#  '2H,3H,4H,5H,6S': [13],
#  '2H,3H,4H,5H,7S': [10],
#  '2H,3H,4H,5H,8S': [12],
#  '2H,3H,4H,5H,9S': [10],
#  '2H,3H,4H,5H,TS': [12],
#  '2H,3H,4H,5H,JS': [12],
#  '2H,3H,4H,5H,QS': [12],
#  '2H,3H,4H,5H,KS': [12],
#  '2H,3H,4H,5H,AS': [7],
#  '2H,3H,4H,5H,2C': [14],
#  '2H,3H,4H,5H,3C': [16],
#  '2H,3H,4H,5H,4C': [16],
#  '2H,3H,4H,5H,5C': [16],
#  '2H,3H,4H,5H,6C': [13],
#  '2H,3H,4H,5H,7C': [10],
#  '2H,3H,4H,5H,8C': [12],
#  '2H,3H,4H,5H,9C': [10],
#  '2H,3H,4H,5H,TC': [12],
#  '2H,3H,4H,5H,JC': [12],
#  '2H,3H,4H,5H,QC': [12],
#  '2H,3H,4H,5H,KC': [12],
#  '2H,3H,4H,5H,AC': [7],
#  '2H,3H,4H,6H,5H': [14],
#  '2H,3H,4H,6H,7H': [12],
#  '2H,3H,4H,6H,8H': [12],
#  '2H,3H,4H,6H,9H': [14],
#  '2H,3H,4H,6H,TH': [12],
#  '2H,3H,4H,6H,JH': [12],
#  '2H,3H,4H,6H,QH': [12],
#  '2H,3H,4H,6H,KH': [12],
#  '2H,3H,4H,6H,AH': [11],
#  '2H,3H,4H,6H,2D': [16],
#  '2H,3H,4H,6H,3D': [16],
#  '2H,3H,4H,6H,4D': [16],
#  '2H,3H,4H,6H,5D': [13],
#  '2H,3H,4H,6H,6D': [15],
#  '2H,3H,4H,6H,7D': [11],
#  '2H,3H,4H,6H,8D': [11],
#  '2H,3H,4H,6H,9D': [13],
#  '2H,3H,4H,6H,TD': [11],
#  '2H,3H,4H,6H,JD': [11],
#  '2H,3H,4H,6H,QD': [11],
#  '2H,3H,4H,6H,KD': [11],
#  '2H,3H,4H,6H,AD': [6],
#  '2H,3H,4H,6H,2S': [16],
#  '2H,3H,4H,6H,3S': [16],
#  '2H,3H,4H,6H,4S': [16],
#  '2H,3H,4H,6H,5S': [13],
#  '2H,3H,4H,6H,6S': [15],
#  '2H,3H,4H,6H,7S': [11],
#  '2H,3H,4H,6H,8S': [11],
#  '2H,3H,4H,6H,9S': [13],
#  '2H,3H,4H,6H,TS': [11],
#  '2H,3H,4H,6H,JS': [11],
#  '2H,3H,4H,6H,QS': [11],
#  '2H,3H,4H,6H,KS': [11],
#  '2H,3H,4H,6H,AS': [6],
#  '2H,3H,4H,6H,2C': [16],
#  '2H,3H,4H,6H,3C': [16],
#  '2H,3H,4H,6H,4C': [16],
#  '2H,3H,4H,6H,5C': [13],
#  '2H,3H,4H,6H,6C': [15],
#  '2H,3H,4H,6H,7C': [11],
#  '2H,3H,4H,6H,8C': [11],
#  '2H,3H,4H,6H,9C': [13],
#  '2H,3H,4H,6H,TC': [11],
#  '2H,3H,4H,6H,JC': [11],
#  '2H,3H,4H,6H,QC': [11],
#  '2H,3H,4H,6H,KC': [11],
#  '2H,3H,4H,6H,AC': [6],
#  '2H,3H,4H,7H,5H': [11],
#  '2H,3H,4H,7H,6H': [12],
#  '2H,3H,4H,7H,8H': [12],
#  '2H,3H,4H,7H,9H': [10],
#  '2H,3H,4H,7H,TH': [10],
#  '2H,3H,4H,7H,JH': [10],
#  '2H,3H,4H,7H,QH': [10],
#  '2H,3H,4H,7H,KH': [10],
#  '2H,3H,4H,7H,AH': [11],
#  '2H,3H,4H,7H,2D': [14],
#  '2H,3H,4H,7H,3D': [14],
#  '2H,3H,4H,7H,4D': [14],
#  '2H,3H,4H,7H,5D': [10],
#  '2H,3H,4H,7H,6D': [11],
#  '2H,3H,4H,7H,7D': [9],
#  '2H,3H,4H,7H,8D': [11],
#  '2H,3H,4H,7H,9D': [9],
#  '2H,3H,4H,7H,TD': [9],
#  '2H,3H,4H,7H,JD': [9],
#  '2H,3H,4H,7H,QD': [9],
#  '2H,3H,4H,7H,KD': [9],
#  '2H,3H,4H,7H,AD': [6],
#  '2H,3H,4H,7H,2S': [14],
#  '2H,3H,4H,7H,3S': [14],
#  '2H,3H,4H,7H,4S': [14],
#  '2H,3H,4H,7H,5S': [10],
#  '2H,3H,4H,7H,6S': [11],
#  '2H,3H,4H,7H,7S': [9],
#  '2H,3H,4H,7H,8S': [11],
#  '2H,3H,4H,7H,9S': [9],
#  '2H,3H,4H,7H,TS': [9],
#  '2H,3H,4H,7H,JS': [9],
#  '2H,3H,4H,7H,QS': [9],
#  '2H,3H,4H,7H,KS': [9],
#  '2H,3H,4H,7H,AS': [6],
#  '2H,3H,4H,7H,2C': [14],
#  '2H,3H,4H,7H,3C': [14],
#  '2H,3H,4H,7H,4C': [14],
#  '2H,3H,4H,7H,5C': [10],
#  '2H,3H,4H,7H,6C': [11],
#  '2H,3H,4H,7H,7C': [9],
#  '2H,3H,4H,7H,8C': [11],
#  '2H,3H,4H,7H,9C': [9],
#  '2H,3H,4H,7H,TC': [9],
#  '2H,3H,4H,7H,JC': [9],
#  '2H,3H,4H,7H,QC': [9],
#  '2H,3H,4H,7H,KC': [9],
#  '2H,3H,4H,7H,AC': [6],
#  '2H,3H,4H,8H,5H': [13],
#  '2H,3H,4H,8H,6H': [12],
#  '2H,3H,4H,8H,7H': [12],
#  '2H,3H,4H,8H,9H': [12],
#  '2H,3H,4H,8H,TH': [12],
#  '2H,3H,4H,8H,JH': [12],
#  '2H,3H,4H,8H,QH': [12],
#  '2H,3H,4H,8H,KH': [12],
#  '2H,3H,4H,8H,AH': [13],
#  '2H,3H,4H,8H,2D': [16],
#  '2H,3H,4H,8H,3D': [16],
#  '2H,3H,4H,8H,4D': [16],
#  '2H,3H,4H,8H,5D': [12],
#  '2H,3H,4H,8H,6D': [11],
#  '2H,3H,4H,8H,7D': [11],
#  '2H,3H,4H,8H,8D': [13],
#  '2H,3H,4H,8H,9D': [11],
#  '2H,3H,4H,8H,TD': [11],
#  '2H,3H,4H,8H,JD': [11],
#  '2H,3H,4H,8H,QD': [11],
#  '2H,3H,4H,8H,KD': [11],
#  '2H,3H,4H,8H,AD': [8],
#  '2H,3H,4H,8H,2S': [16],
#  '2H,3H,4H,8H,3S': [16],
#  '2H,3H,4H,8H,4S': [16],
#  '2H,3H,4H,8H,5S': [12],
#  '2H,3H,4H,8H,6S': [11],
#  '2H,3H,4H,8H,7S': [11],
#  '2H,3H,4H,8H,8S': [13],
#  '2H,3H,4H,8H,9S': [11],
#  '2H,3H,4H,8H,TS': [11],
#  '2H,3H,4H,8H,JS': [11],
#  '2H,3H,4H,8H,QS': [11],
#  '2H,3H,4H,8H,KS': [11],
#  '2H,3H,4H,8H,AS': [8],
#  '2H,3H,4H,8H,2C': [16],
#  '2H,3H,4H,8H,3C': [16],
#  '2H,3H,4H,8H,4C': [16],
#  '2H,3H,4H,8H,5C': [12],
#  '2H,3H,4H,8H,6C': [11],
#  '2H,3H,4H,8H,7C': [11],
#  '2H,3H,4H,8H,8C': [13],
#  '2H,3H,4H,8H,9C': [11],
#  '2H,3H,4H,8H,TC': [11],
#  '2H,3H,4H,8H,JC': [11],
#  '2H,3H,4H,8H,QC': [11],
#  '2H,3H,4H,8H,KC': [11],
#  '2H,3H,4H,8H,AC': [8],
#  '2H,3H,4H,9H,5H': [11],
#  '2H,3H,4H,9H,6H': [14],
#  '2H,3H,4H,9H,7H': [10],
#  '2H,3H,4H,9H,8H': [12],
#  '2H,3H,4H,9H,TH': [12],
#  '2H,3H,4H,9H,JH': [12],
#  '2H,3H,4H,9H,QH': [12],
#  '2H,3H,4H,9H,KH': [12],
#  '2H,3H,4H,9H,AH': [13],
#  '2H,3H,4H,9H,2D': [16],
#  '2H,3H,4H,9H,3D': [16],
#  '2H,3H,4H,9H,4D': [16],
#  '2H,3H,4H,9H,5D': [10],
#  '2H,3H,4H,9H,6D': [13],
#  '2H,3H,4H,9H,7D': [9],
#  '2H,3H,4H,9H,8D': [11],
#  '2H,3H,4H,9H,9D': [13],
#  '2H,3H,4H,9H,TD': [11],
#  '2H,3H,4H,9H,JD': [11],
#  '2H,3H,4H,9H,QD': [11],
#  '2H,3H,4H,9H,KD': [11],
#  '2H,3H,4H,9H,AD': [8],
#  '2H,3H,4H,9H,2S': [16],
#  '2H,3H,4H,9H,3S': [16],
#  '2H,3H,4H,9H,4S': [16],
#  '2H,3H,4H,9H,5S': [10],
#  '2H,3H,4H,9H,6S': [13],
#  '2H,3H,4H,9H,7S': [9],
#  '2H,3H,4H,9H,8S': [11],
#  '2H,3H,4H,9H,9S': [13],
#  '2H,3H,4H,9H,TS': [11],
#  '2H,3H,4H,9H,JS': [11],
#  '2H,3H,4H,9H,QS': [11],
#  '2H,3H,4H,9H,KS': [11],
#  '2H,3H,4H,9H,AS': [8],
#  '2H,3H,4H,9H,2C': [16],
#  '2H,3H,4H,9H,3C': [16],
#  '2H,3H,4H,9H,4C': [16],
#  '2H,3H,4H,9H,5C': [10],
#  '2H,3H,4H,9H,6C': [13],
#  '2H,3H,4H,9H,7C': [9],
#  '2H,3H,4H,9H,8C': [11],
#  '2H,3H,4H,9H,9C': [13],
#  '2H,3H,4H,9H,TC': [11],
#  '2H,3H,4H,9H,JC': [11],
#  '2H,3H,4H,9H,QC': [11],
#  '2H,3H,4H,9H,KC': [11],
#  '2H,3H,4H,9H,AC': [8],
#  '2H,3H,4H,TH,5H': [13],
#  '2H,3H,4H,TH,6H': [12],
#  '2H,3H,4H,TH,7H': [10],
#  '2H,3H,4H,TH,8H': [12],
#  '2H,3H,4H,TH,9H': [12],
#  '2H,3H,4H,TH,JH': [12],
#  '2H,3H,4H,TH,QH': [12],
#  '2H,3H,4H,TH,KH': [12],
#  '2H,3H,4H,TH,AH': [13],
#  '2H,3H,4H,TH,2D': [16],
#  '2H,3H,4H,TH,3D': [16],
#  '2H,3H,4H,TH,4D': [14],
#  '2H,3H,4H,TH,5D': [12],
#  '2H,3H,4H,TH,6D': [11],
#  '2H,3H,4H,TH,7D': [9],
#  '2H,3H,4H,TH,8D': [11],
#  '2H,3H,4H,TH,9D': [11],
#  '2H,3H,4H,TH,TD': [13],
#  '2H,3H,4H,TH,JD': [11],
#  '2H,3H,4H,TH,QD': [11],
#  '2H,3H,4H,TH,KD': [11],
#  '2H,3H,4H,TH,AD': [8],
#  '2H,3H,4H,TH,2S': [16],
#  '2H,3H,4H,TH,3S': [16],
#  '2H,3H,4H,TH,4S': [14],
#  '2H,3H,4H,TH,5S': [12],
#  '2H,3H,4H,TH,6S': [11],
#  '2H,3H,4H,TH,7S': [9],
#  '2H,3H,4H,TH,8S': [11],
#  '2H,3H,4H,TH,9S': [11],
#  '2H,3H,4H,TH,TS': [13],
#  '2H,3H,4H,TH,JS': [11],
#  '2H,3H,4H,TH,QS': [11],
#  '2H,3H,4H,TH,KS': [11],
#  '2H,3H,4H,TH,AS': [8],
#  '2H,3H,4H,TH,2C': [16],
#  '2H,3H,4H,TH,3C': [16],
#  '2H,3H,4H,TH,4C': [14],
#  '2H,3H,4H,TH,5C': [12],
#  '2H,3H,4H,TH,6C': [11],
#  '2H,3H,4H,TH,7C': [9],
#  '2H,3H,4H,TH,8C': [11],
#  '2H,3H,4H,TH,9C': [11],
#  '2H,3H,4H,TH,TC': [13],
#  '2H,3H,4H,TH,JC': [11],
#  '2H,3H,4H,TH,QC': [11],
#  '2H,3H,4H,TH,KC': [11],
#  '2H,3H,4H,TH,AC': [8],
#  '2H,3H,4H,JH,5H': [14],
#  '2H,3H,4H,JH,6H': [13],
#  '2H,3H,4H,JH,7H': [11],
#  '2H,3H,4H,JH,8H': [13],
#  '2H,3H,4H,JH,9H': [13],
#  '2H,3H,4H,JH,TH': [13],
#  '2H,3H,4H,JH,QH': [13],
#  '2H,3H,4H,JH,KH': [13],
#  '2H,3H,4H,JH,AH': [14],
#  '2H,3H,4H,JH,2D': [16],
#  '2H,3H,4H,JH,3D': [16],
#  '2H,3H,4H,JH,4D': [14],
#  '2H,3H,4H,JH,5D': [12],
#  '2H,3H,4H,JH,6D': [11],
#  '2H,3H,4H,JH,7D': [9],
#  '2H,3H,4H,JH,8D': [11],
#  '2H,3H,4H,JH,9D': [11],
#  '2H,3H,4H,JH,TD': [11],
#  '2H,3H,4H,JH,JD': [13],
#  '2H,3H,4H,JH,QD': [11],
#  '2H,3H,4H,JH,KD': [11],
#  '2H,3H,4H,JH,AD': [8],
#  '2H,3H,4H,JH,2S': [16],
#  '2H,3H,4H,JH,3S': [16],
#  '2H,3H,4H,JH,4S': [14],
#  '2H,3H,4H,JH,5S': [12],
#  '2H,3H,4H,JH,6S': [11],
#  '2H,3H,4H,JH,7S': [9],
#  '2H,3H,4H,JH,8S': [11],
#  '2H,3H,4H,JH,9S': [11],
#  '2H,3H,4H,JH,TS': [11],
#  '2H,3H,4H,JH,JS': [13],
#  '2H,3H,4H,JH,QS': [11],
#  '2H,3H,4H,JH,KS': [11],
#  '2H,3H,4H,JH,AS': [8],
#  '2H,3H,4H,JH,2C': [16],
#  '2H,3H,4H,JH,3C': [16],
#  '2H,3H,4H,JH,4C': [14],
#  '2H,3H,4H,JH,5C': [12],
#  '2H,3H,4H,JH,6C': [11],
#  '2H,3H,4H,JH,7C': [9],
#  '2H,3H,4H,JH,8C': [11],
#  '2H,3H,4H,JH,9C': [11],
#  '2H,3H,4H,JH,TC': [11],
#  '2H,3H,4H,JH,JC': [13],
#  '2H,3H,4H,JH,QC': [11],
#  '2H,3H,4H,JH,KC': [11],
#  '2H,3H,4H,JH,AC': [8],
#  '2H,3H,4H,QH,5H': [13],
#  '2H,3H,4H,QH,6H': [12],
#  '2H,3H,4H,QH,7H': [10],
#  '2H,3H,4H,QH,8H': [12],
#  '2H,3H,4H,QH,9H': [12],
#  '2H,3H,4H,QH,TH': [12],
#  '2H,3H,4H,QH,JH': [12],
#  '2H,3H,4H,QH,KH': [12],
#  '2H,3H,4H,QH,AH': [13],
#  '2H,3H,4H,QH,2D': [16],
#  '2H,3H,4H,QH,3D': [16],
#  '2H,3H,4H,QH,4D': [14],
#  '2H,3H,4H,QH,5D': [12],
#  '2H,3H,4H,QH,6D': [11],
#  '2H,3H,4H,QH,7D': [9],
#  '2H,3H,4H,QH,8D': [11],
#  '2H,3H,4H,QH,9D': [11],
#  '2H,3H,4H,QH,TD': [11],
#  '2H,3H,4H,QH,JD': [11],
#  '2H,3H,4H,QH,QD': [13],
#  '2H,3H,4H,QH,KD': [11],
#  '2H,3H,4H,QH,AD': [8],
#  '2H,3H,4H,QH,2S': [16],
#  '2H,3H,4H,QH,3S': [16],
#  '2H,3H,4H,QH,4S': [14],
#  '2H,3H,4H,QH,5S': [12],
#  '2H,3H,4H,QH,6S': [11],
#  '2H,3H,4H,QH,7S': [9],
#  '2H,3H,4H,QH,8S': [11],
#  '2H,3H,4H,QH,9S': [11],
#  '2H,3H,4H,QH,TS': [11],
#  '2H,3H,4H,QH,JS': [11],
#  '2H,3H,4H,QH,QS': [13],
#  '2H,3H,4H,QH,KS': [11],
#  '2H,3H,4H,QH,AS': [8],
#  '2H,3H,4H,QH,2C': [16],
#  '2H,3H,4H,QH,3C': [16],
#  '2H,3H,4H,QH,4C': [14],
#  '2H,3H,4H,QH,5C': [12],
#  '2H,3H,4H,QH,6C': [11],
#  '2H,3H,4H,QH,7C': [9],
#  '2H,3H,4H,QH,8C': [11],
#  '2H,3H,4H,QH,9C': [11],
#  '2H,3H,4H,QH,TC': [11],
#  '2H,3H,4H,QH,JC': [11],
#  '2H,3H,4H,QH,QC': [13],
#  '2H,3H,4H,QH,KC': [11],
#  '2H,3H,4H,QH,AC': [8],
#  '2H,3H,4H,KH,5H': [13],
#  '2H,3H,4H,KH,6H': [12],
#  '2H,3H,4H,KH,7H': [10],
#  '2H,3H,4H,KH,8H': [12],
#  '2H,3H,4H,KH,9H': [12],
#  '2H,3H,4H,KH,TH': [12],
#  '2H,3H,4H,KH,JH': [12],
#  '2H,3H,4H,KH,QH': [12],
#  '2H,3H,4H,KH,AH': [13],
#  '2H,3H,4H,KH,2D': [16],
#  '2H,3H,4H,KH,3D': [16],
#  '2H,3H,4H,KH,4D': [14],
#  '2H,3H,4H,KH,5D': [12],
#  '2H,3H,4H,KH,6D': [11],
#  '2H,3H,4H,KH,7D': [9],
#  '2H,3H,4H,KH,8D': [11],
#  '2H,3H,4H,KH,9D': [11],
#  '2H,3H,4H,KH,TD': [11],
#  '2H,3H,4H,KH,JD': [11],
#  '2H,3H,4H,KH,QD': [11],
#  '2H,3H,4H,KH,KD': [13],
#  '2H,3H,4H,KH,AD': [8],
#  '2H,3H,4H,KH,2S': [16],
#  '2H,3H,4H,KH,3S': [16],
#  '2H,3H,4H,KH,4S': [14],
#  '2H,3H,4H,KH,5S': [12],
#  '2H,3H,4H,KH,6S': [11],
#  '2H,3H,4H,KH,7S': [9],
#  '2H,3H,4H,KH,8S': [11],
#  '2H,3H,4H,KH,9S': [11],
#  '2H,3H,4H,KH,TS': [11],
#  '2H,3H,4H,KH,JS': [11],
#  '2H,3H,4H,KH,QS': [11],
#  '2H,3H,4H,KH,KS': [13],
#  '2H,3H,4H,KH,AS': [8],
#  '2H,3H,4H,KH,2C': [16],
#  '2H,3H,4H,KH,3C': [16],
#  '2H,3H,4H,KH,4C': [14],
#  '2H,3H,4H,KH,5C': [12],
#  '2H,3H,4H,KH,6C': [11],
#  '2H,3H,4H,KH,7C': [9],
#  '2H,3H,4H,KH,8C': [11],
#  '2H,3H,4H,KH,9C': [11],
#  '2H,3H,4H,KH,TC': [11],
#  '2H,3H,4H,KH,JC': [11],
#  '2H,3H,4H,KH,QC': [11],
#  '2H,3H,4H,KH,KC': [13],
#  '2H,3H,4H,KH,AC': [8],
#  '2H,3H,4H,AH,5H': [12],
#  '2H,3H,4H,AH,6H': [11],
#  '2H,3H,4H,AH,7H': [11],
#  '2H,3H,4H,AH,8H': [13],
#  '2H,3H,4H,AH,9H': [13],
#  '2H,3H,4H,AH,TH': [13],
#  '2H,3H,4H,AH,JH': [13],
#  '2H,3H,4H,AH,QH': [13],
#  '2H,3H,4H,AH,KH': [13],
#  '2H,3H,4H,AH,2D': [14],
#  '2H,3H,4H,AH,3D': [14],
#  '2H,3H,4H,AH,4D': [14],
#  '2H,3H,4H,AH,5D': [11],
#  '2H,3H,4H,AH,6D': [10],
#  '2H,3H,4H,AH,7D': [10],
#  '2H,3H,4H,AH,8D': [12],
#  '2H,3H,4H,AH,9D': [12],
#  '2H,3H,4H,AH,TD': [12],
#  '2H,3H,4H,AH,JD': [12],
#  '2H,3H,4H,AH,QD': [12],
#  '2H,3H,4H,AH,KD': [12],
#  '2H,3H,4H,AH,AD': [14],
#  '2H,3H,4H,AH,2S': [14],
#  '2H,3H,4H,AH,3S': [14],
#  '2H,3H,4H,AH,4S': [14],
#  '2H,3H,4H,AH,5S': [11],
#  '2H,3H,4H,AH,6S': [10],
#  '2H,3H,4H,AH,7S': [10],
#  '2H,3H,4H,AH,8S': [12],
#  '2H,3H,4H,AH,9S': [12],
#  '2H,3H,4H,AH,TS': [12],
#  '2H,3H,4H,AH,JS': [12],
#  '2H,3H,4H,AH,QS': [12],
#  '2H,3H,4H,AH,KS': [12],
#  '2H,3H,4H,AH,AS': [14],
#  '2H,3H,4H,AH,2C': [14],
#  '2H,3H,4H,AH,3C': [14],
#  '2H,3H,4H,AH,4C': [14],
#  '2H,3H,4H,AH,5C': [11],
#  '2H,3H,4H,AH,6C': [10],
#  '2H,3H,4H,AH,7C': [10],
#  '2H,3H,4H,AH,8C': [12],
#  '2H,3H,4H,AH,9C': [12],
#  '2H,3H,4H,AH,TC': [12],
#  '2H,3H,4H,AH,JC': [12],
#  '2H,3H,4H,AH,QC': [12],
#  '2H,3H,4H,AH,KC': [12],
#  '2H,3H,4H,AH,AC': [14],
#  '2H,3H,4H,2D,5H': [10],
#  '2H,3H,4H,2D,6H': [12],
#  '2H,3H,4H,2D,7H': [10],
#  '2H,3H,4H,2D,8H': [12],
#  '2H,3H,4H,2D,9H': [12],
#  '2H,3H,4H,2D,TH': [12],
#  '2H,3H,4H,2D,JH': [12],
#  '2H,3H,4H,2D,QH': [12],
#  '2H,3H,4H,2D,KH': [12],
#  '2H,3H,4H,2D,AH': [10],
#  '2H,3H,4H,2D,3D': [16],
#  '2H,3H,4H,2D,4D': [18],
#  '2H,3H,4H,2D,5D': [10],
#  '2H,3H,4H,2D,6D': [12],
#  '2H,3H,4H,2D,7D': [10],
#  '2H,3H,4H,2D,8D': [12],
#  '2H,3H,4H,2D,9D': [12],
#  '2H,3H,4H,2D,TD': [12],
#  '2H,3H,4H,2D,JD': [12],
#  '2H,3H,4H,2D,QD': [12],
#  '2H,3H,4H,2D,KD': [12],
#  '2H,3H,4H,2D,AD': [10],
#  '2H,3H,4H,2D,2S': [15],
#  '2H,3H,4H,2D,3S': [16],
#  '2H,3H,4H,2D,4S': [18],
#  '2H,3H,4H,2D,5S': [10],
#  '2H,3H,4H,2D,6S': [12],
#  '2H,3H,4H,2D,7S': [10],
#  '2H,3H,4H,2D,8S': [12],
#  '2H,3H,4H,2D,9S': [12],
#  '2H,3H,4H,2D,TS': [12],
#  '2H,3H,4H,2D,JS': [12],
#  '2H,3H,4H,2D,QS': [12],
#  '2H,3H,4H,2D,KS': [12],
#  '2H,3H,4H,2D,AS': [10],
#  '2H,3H,4H,2D,2C': [15],
#  '2H,3H,4H,2D,3C': [16],
#  '2H,3H,4H,2D,4C': [18],
#  '2H,3H,4H,2D,5C': [10],
#  '2H,3H,4H,2D,6C': [12],
#  '2H,3H,4H,2D,7C': [10],
#  '2H,3H,4H,2D,8C': [12],
#  '2H,3H,4H,2D,9C': [12],
#  '2H,3H,4H,2D,TC': [12],
#  '2H,3H,4H,2D,JC': [12],
#  '2H,3H,4H,2D,QC': [12],
#  '2H,3H,4H,2D,KC': [12],
#  '2H,3H,4H,2D,AC': [10],
#  '2H,3H,4H,3D,5H': [12],
#  '2H,3H,4H,3D,6H': [12],
#  '2H,3H,4H,3D,7H': [10],
#  '2H,3H,4H,3D,8H': [12],
#  '2H,3H,4H,3D,9H': [12],
#  '2H,3H,4H,3D,TH': [12],
#  '2H,3H,4H,3D,JH': [12],
#  '2H,3H,4H,3D,QH': [12],
#  '2H,3H,4H,3D,KH': [12],
#  '2H,3H,4H,3D,AH': [10],
#  '2H,3H,4H,3D,2D': [16],
#  '2H,3H,4H,3D,4D': [16],
#  '2H,3H,4H,3D,5D': [12],
#  '2H,3H,4H,3D,6D': [12],
#  '2H,3H,4H,3D,7D': [10],
#  '2H,3H,4H,3D,8D': [12],
#  '2H,3H,4H,3D,9D': [12],
#  '2H,3H,4H,3D,TD': [12],
#  '2H,3H,4H,3D,JD': [12],
#  '2H,3H,4H,3D,QD': [12],
#  '2H,3H,4H,3D,KD': [12],
#  '2H,3H,4H,3D,AD': [10],
#  '2H,3H,4H,3D,2S': [16],
#  '2H,3H,4H,3D,3S': [17],
#  '2H,3H,4H,3D,4S': [16],
#  '2H,3H,4H,3D,5S': [12],
#  '2H,3H,4H,3D,6S': [12],
#  '2H,3H,4H,3D,7S': [10],
#  '2H,3H,4H,3D,8S': [12],
#  '2H,3H,4H,3D,9S': [12],
#  '2H,3H,4H,3D,TS': [12],
#  '2H,3H,4H,3D,JS': [12],
#  '2H,3H,4H,3D,QS': [12],
#  '2H,3H,4H,3D,KS': [12],
#  '2H,3H,4H,3D,AS': [10],
#  '2H,3H,4H,3D,2C': [16],
#  '2H,3H,4H,3D,3C': [17],
#  '2H,3H,4H,3D,4C': [16],
#  '2H,3H,4H,3D,5C': [12],
#  '2H,3H,4H,3D,6C': [12],
#  '2H,3H,4H,3D,7C': [10],
#  '2H,3H,4H,3D,8C': [12],
#  '2H,3H,4H,3D,9C': [12],
#  '2H,3H,4H,3D,TC': [12],
#  '2H,3H,4H,3D,JC': [12],
#  '2H,3H,4H,3D,QC': [12],
#  '2H,3H,4H,3D,KC': [12],
#  '2H,3H,4H,3D,AC': [10],
#  '2H,3H,4H,4D,5H': [12],
#  '2H,3H,4H,4D,6H': [12],
#  '2H,3H,4H,4D,7H': [10],
#  '2H,3H,4H,4D,8H': [12],
#  '2H,3H,4H,4D,9H': [12],
#  '2H,3H,4H,4D,TH': [10],
#  '2H,3H,4H,4D,JH': [10],
#  '2H,3H,4H,4D,QH': [10],
#  '2H,3H,4H,4D,KH': [10],
#  '2H,3H,4H,4D,AH': [10],
#  '2H,3H,4H,4D,2D': [18],
#  '2H,3H,4H,4D,3D': [16],
#  '2H,3H,4H,4D,5D': [12],
#  '2H,3H,4H,4D,6D': [12],
#  '2H,3H,4H,4D,7D': [10],
#  '2H,3H,4H,4D,8D': [12],
#  '2H,3H,4H,4D,9D': [12],
#  '2H,3H,4H,4D,TD': [10],
#  '2H,3H,4H,4D,JD': [10],
#  '2H,3H,4H,4D,QD': [10],
#  '2H,3H,4H,4D,KD': [10],
#  '2H,3H,4H,4D,AD': [10],
#  '2H,3H,4H,4D,2S': [18],
#  '2H,3H,4H,4D,3S': [16],
#  '2H,3H,4H,4D,4S': [17],
#  '2H,3H,4H,4D,5S': [12],
#  '2H,3H,4H,4D,6S': [12],
#  '2H,3H,4H,4D,7S': [10],
#  '2H,3H,4H,4D,8S': [12],
#  '2H,3H,4H,4D,9S': [12],
#  '2H,3H,4H,4D,TS': [10],
#  '2H,3H,4H,4D,JS': [10],
#  '2H,3H,4H,4D,QS': [10],
#  '2H,3H,4H,4D,KS': [10],
#  '2H,3H,4H,4D,AS': [10],
#  '2H,3H,4H,4D,2C': [18],
#  '2H,3H,4H,4D,3C': [16],
#  '2H,3H,4H,4D,4C': [17],
#  '2H,3H,4H,4D,5C': [12],
#  '2H,3H,4H,4D,6C': [12],
#  '2H,3H,4H,4D,7C': [10],
#  '2H,3H,4H,4D,8C': [12],
#  '2H,3H,4H,4D,9C': [12],
#  '2H,3H,4H,4D,TC': [10],
#  '2H,3H,4H,4D,JC': [10],
#  '2H,3H,4H,4D,QC': [10],
#  '2H,3H,4H,4D,KC': [10],
#  '2H,3H,4H,4D,AC': [10],
#  '2H,3H,4H,5D,5H': [12],
#  '2H,3H,4H,5D,6H': [9],
#  '2H,3H,4H,5D,7H': [6],
#  '2H,3H,4H,5D,8H': [8],
#  '2H,3H,4H,5D,9H': [6],
#  '2H,3H,4H,5D,TH': [8],
#  '2H,3H,4H,5D,JH': [8],
#  '2H,3H,4H,5D,QH': [8],
#  '2H,3H,4H,5D,KH': [8],
#  '2H,3H,4H,5D,AH': [7],
#  '2H,3H,4H,5D,2D': [10],
#  '2H,3H,4H,5D,3D': [12],
#  '2H,3H,4H,5D,4D': [12],
#  '2H,3H,4H,5D,6D': [9],
#  '2H,3H,4H,5D,7D': [6],
#  '2H,3H,4H,5D,8D': [8],
#  '2H,3H,4H,5D,9D': [6],
#  '2H,3H,4H,5D,TD': [8],
#  '2H,3H,4H,5D,JD': [8],
#  '2H,3H,4H,5D,QD': [8],
#  '2H,3H,4H,5D,KD': [8],
#  '2H,3H,4H,5D,AD': [7],
#  '2H,3H,4H,5D,2S': [10],
#  '2H,3H,4H,5D,3S': [12],
#  '2H,3H,4H,5D,4S': [12],
#  '2H,3H,4H,5D,5S': [12],
#  '2H,3H,4H,5D,6S': [9],
#  '2H,3H,4H,5D,7S': [6],
#  '2H,3H,4H,5D,8S': [8],
#  '2H,3H,4H,5D,9S': [6],
#  '2H,3H,4H,5D,TS': [8],
#  '2H,3H,4H,5D,JS': [8],
#  '2H,3H,4H,5D,QS': [8],
#  '2H,3H,4H,5D,KS': [8],
#  '2H,3H,4H,5D,AS': [7],
#  '2H,3H,4H,5D,2C': [10],
#  '2H,3H,4H,5D,3C': [12],
#  '2H,3H,4H,5D,4C': [12],
#  '2H,3H,4H,5D,5C': [12],
#  '2H,3H,4H,5D,6C': [9],
#  '2H,3H,4H,5D,7C': [6],
#  '2H,3H,4H,5D,8C': [8],
#  '2H,3H,4H,5D,9C': [6],
#  '2H,3H,4H,5D,TC': [8],
#  '2H,3H,4H,5D,JC': [8],
#  '2H,3H,4H,5D,QC': [8],
#  '2H,3H,4H,5D,KC': [8],
#  '2H,3H,4H,5D,AC': [7],
#  '2H,3H,4H,6D,5H': [9],
#  '2H,3H,4H,6D,6H': [11],
#  '2H,3H,4H,6D,7H': [7],
#  '2H,3H,4H,6D,8H': [7],
#  '2H,3H,4H,6D,9H': [9],
#  '2H,3H,4H,6D,TH': [7],
#  '2H,3H,4H,6D,JH': [7],
#  '2H,3H,4H,6D,QH': [7],
#  '2H,3H,4H,6D,KH': [7],
#  '2H,3H,4H,6D,AH': [6],
#  '2H,3H,4H,6D,2D': [12],
#  '2H,3H,4H,6D,3D': [12],
#  '2H,3H,4H,6D,4D': [12],
#  '2H,3H,4H,6D,5D': [9],
#  '2H,3H,4H,6D,7D': [7],
#  '2H,3H,4H,6D,8D': [7],
#  '2H,3H,4H,6D,9D': [9],
#  '2H,3H,4H,6D,TD': [7],
#  '2H,3H,4H,6D,JD': [7],
#  '2H,3H,4H,6D,QD': [7],
#  '2H,3H,4H,6D,KD': [7],
#  '2H,3H,4H,6D,AD': [6],
#  '2H,3H,4H,6D,2S': [12],
#  '2H,3H,4H,6D,3S': [12],
#  '2H,3H,4H,6D,4S': [12],
#  '2H,3H,4H,6D,5S': [9],
#  '2H,3H,4H,6D,6S': [11],
#  '2H,3H,4H,6D,7S': [7],
#  '2H,3H,4H,6D,8S': [7],
#  '2H,3H,4H,6D,9S': [9],
#  '2H,3H,4H,6D,TS': [7],
#  '2H,3H,4H,6D,JS': [7],
#  '2H,3H,4H,6D,QS': [7],
#  '2H,3H,4H,6D,KS': [7],
#  '2H,3H,4H,6D,AS': [6],
#  '2H,3H,4H,6D,2C': [12],
#  '2H,3H,4H,6D,3C': [12],
#  '2H,3H,4H,6D,4C': [12],
#  '2H,3H,4H,6D,5C': [9],
#  '2H,3H,4H,6D,6C': [11],
#  '2H,3H,4H,6D,7C': [7],
#  '2H,3H,4H,6D,8C': [7],
#  '2H,3H,4H,6D,9C': [9],
#  '2H,3H,4H,6D,TC': [7],
#  '2H,3H,4H,6D,JC': [7],
#  '2H,3H,4H,6D,QC': [7],
#  '2H,3H,4H,6D,KC': [7],
#  '2H,3H,4H,6D,AC': [6],
#  '2H,3H,4H,7D,5H': [6],
#  '2H,3H,4H,7D,6H': [7],
#  '2H,3H,4H,7D,7H': [5],
#  '2H,3H,4H,7D,8H': [7],
#  '2H,3H,4H,7D,9H': [5],
#  '2H,3H,4H,7D,TH': [5],
#  '2H,3H,4H,7D,JH': [5],
#  '2H,3H,4H,7D,QH': [5],
#  '2H,3H,4H,7D,KH': [5],
#  '2H,3H,4H,7D,AH': [6],
#  '2H,3H,4H,7D,2D': [10],
#  '2H,3H,4H,7D,3D': [10],
#  '2H,3H,4H,7D,4D': [10],
#  '2H,3H,4H,7D,5D': [6],
#  '2H,3H,4H,7D,6D': [7],
#  '2H,3H,4H,7D,8D': [7],
#  '2H,3H,4H,7D,9D': [5],
#  '2H,3H,4H,7D,TD': [5],
#  '2H,3H,4H,7D,JD': [5],
#  '2H,3H,4H,7D,QD': [5],
#  '2H,3H,4H,7D,KD': [5],
#  '2H,3H,4H,7D,AD': [6],
#  '2H,3H,4H,7D,2S': [10],
#  '2H,3H,4H,7D,3S': [10],
#  '2H,3H,4H,7D,4S': [10],
#  '2H,3H,4H,7D,5S': [6],
#  '2H,3H,4H,7D,6S': [7],
#  '2H,3H,4H,7D,7S': [5],
#  '2H,3H,4H,7D,8S': [7],
#  '2H,3H,4H,7D,9S': [5],
#  '2H,3H,4H,7D,TS': [5],
#  '2H,3H,4H,7D,JS': [5],
#  '2H,3H,4H,7D,QS': [5],
#  '2H,3H,4H,7D,KS': [5],
#  '2H,3H,4H,7D,AS': [6],
#  '2H,3H,4H,7D,2C': [10],
#  '2H,3H,4H,7D,3C': [10],
#  '2H,3H,4H,7D,4C': [10],
#  '2H,3H,4H,7D,5C': [6],
#  '2H,3H,4H,7D,6C': [7],
#  '2H,3H,4H,7D,7C': [5],
#  '2H,3H,4H,7D,8C': [7],
#  '2H,3H,4H,7D,9C': [5],
#  '2H,3H,4H,7D,TC': [5],
#  '2H,3H,4H,7D,JC': [5],
#  '2H,3H,4H,7D,QC': [5],
#  '2H,3H,4H,7D,KC': [5],
#  '2H,3H,4H,7D,AC': [6],
#  '2H,3H,4H,8D,5H': [8],
#  '2H,3H,4H,8D,6H': [7],
#  '2H,3H,4H,8D,7H': [7],
#  '2H,3H,4H,8D,8H': [9],
#  '2H,3H,4H,8D,9H': [7],
#  '2H,3H,4H,8D,TH': [7],
#  '2H,3H,4H,8D,JH': [7],
#  '2H,3H,4H,8D,QH': [7],
#  '2H,3H,4H,8D,KH': [7],
#  '2H,3H,4H,8D,AH': [8],
#  '2H,3H,4H,8D,2D': [12],
#  '2H,3H,4H,8D,3D': [12],
#  '2H,3H,4H,8D,4D': [12],
#  '2H,3H,4H,8D,5D': [8],
#  '2H,3H,4H,8D,6D': [7],
#  '2H,3H,4H,8D,7D': [7],
#  '2H,3H,4H,8D,9D': [7],
#  '2H,3H,4H,8D,TD': [7],
#  '2H,3H,4H,8D,JD': [7],
#  '2H,3H,4H,8D,QD': [7],
#  '2H,3H,4H,8D,KD': [7],
#  '2H,3H,4H,8D,AD': [8],
#  '2H,3H,4H,8D,2S': [12],
#  '2H,3H,4H,8D,3S': [12],
#  '2H,3H,4H,8D,4S': [12],
#  '2H,3H,4H,8D,5S': [8],
#  '2H,3H,4H,8D,6S': [7],
#  '2H,3H,4H,8D,7S': [7],
#  '2H,3H,4H,8D,8S': [9],
#  '2H,3H,4H,8D,9S': [7],
#  '2H,3H,4H,8D,TS': [7],
#  '2H,3H,4H,8D,JS': [7],
#  '2H,3H,4H,8D,QS': [7],
#  '2H,3H,4H,8D,KS': [7],
#  '2H,3H,4H,8D,AS': [8],
#  '2H,3H,4H,8D,2C': [12],
#  '2H,3H,4H,8D,3C': [12],
#  '2H,3H,4H,8D,4C': [12],
#  '2H,3H,4H,8D,5C': [8],
#  '2H,3H,4H,8D,6C': [7],
#  '2H,3H,4H,8D,7C': [7],
#  '2H,3H,4H,8D,8C': [9],
#  '2H,3H,4H,8D,9C': [7],
#  '2H,3H,4H,8D,TC': [7],
#  '2H,3H,4H,8D,JC': [7],
#  '2H,3H,4H,8D,QC': [7],
#  '2H,3H,4H,8D,KC': [7],
#  '2H,3H,4H,8D,AC': [8],
#  '2H,3H,4H,9D,5H': [6],
#  '2H,3H,4H,9D,6H': [9],
#  '2H,3H,4H,9D,7H': [5],
#  '2H,3H,4H,9D,8H': [7],
#  '2H,3H,4H,9D,9H': [9],
#  '2H,3H,4H,9D,TH': [7],
#  '2H,3H,4H,9D,JH': [7],
#  '2H,3H,4H,9D,QH': [7],
#  '2H,3H,4H,9D,KH': [7],
#  '2H,3H,4H,9D,AH': [8],
#  '2H,3H,4H,9D,2D': [12],
#  '2H,3H,4H,9D,3D': [12],
#  '2H,3H,4H,9D,4D': [12],
#  '2H,3H,4H,9D,5D': [6],
#  '2H,3H,4H,9D,6D': [9],
#  '2H,3H,4H,9D,7D': [5],
#  '2H,3H,4H,9D,8D': [7],
#  '2H,3H,4H,9D,TD': [7],
#  '2H,3H,4H,9D,JD': [7],
#  '2H,3H,4H,9D,QD': [7],
#  '2H,3H,4H,9D,KD': [7],
#  '2H,3H,4H,9D,AD': [8],
#  '2H,3H,4H,9D,2S': [12],
#  '2H,3H,4H,9D,3S': [12],
#  '2H,3H,4H,9D,4S': [12],
#  '2H,3H,4H,9D,5S': [6],
#  '2H,3H,4H,9D,6S': [9],
#  '2H,3H,4H,9D,7S': [5],
#  '2H,3H,4H,9D,8S': [7],
#  '2H,3H,4H,9D,9S': [9],
#  '2H,3H,4H,9D,TS': [7],
#  '2H,3H,4H,9D,JS': [7],
#  '2H,3H,4H,9D,QS': [7],
#  '2H,3H,4H,9D,KS': [7],
#  '2H,3H,4H,9D,AS': [8],
#  '2H,3H,4H,9D,2C': [12],
#  '2H,3H,4H,9D,3C': [12],
#  '2H,3H,4H,9D,4C': [12],
#  '2H,3H,4H,9D,5C': [6],
#  '2H,3H,4H,9D,6C': [9],
#  '2H,3H,4H,9D,7C': [5],
#  '2H,3H,4H,9D,8C': [7],
#  '2H,3H,4H,9D,9C': [9],
#  '2H,3H,4H,9D,TC': [7],
#  '2H,3H,4H,9D,JC': [7],
#  '2H,3H,4H,9D,QC': [7],
#  '2H,3H,4H,9D,KC': [7],
#  '2H,3H,4H,9D,AC': [8],
#  '2H,3H,4H,TD,5H': [8],
#  '2H,3H,4H,TD,6H': [7],
#  '2H,3H,4H,TD,7H': [5],
#  '2H,3H,4H,TD,8H': [7],
#  '2H,3H,4H,TD,9H': [7],
#  '2H,3H,4H,TD,TH': [9],
#  '2H,3H,4H,TD,JH': [7],
#  '2H,3H,4H,TD,QH': [7],
#  '2H,3H,4H,TD,KH': [7],
#  '2H,3H,4H,TD,AH': [8],
#  '2H,3H,4H,TD,2D': [12],
#  '2H,3H,4H,TD,3D': [12],
#  '2H,3H,4H,TD,4D': [10],
#  '2H,3H,4H,TD,5D': [8],
#  '2H,3H,4H,TD,6D': [7],
#  '2H,3H,4H,TD,7D': [5],
#  '2H,3H,4H,TD,8D': [7],
#  '2H,3H,4H,TD,9D': [7],
#  '2H,3H,4H,TD,JD': [7],
#  '2H,3H,4H,TD,QD': [7],
#  '2H,3H,4H,TD,KD': [7],
#  '2H,3H,4H,TD,AD': [8],
#  '2H,3H,4H,TD,2S': [12],
#  '2H,3H,4H,TD,3S': [12],
#  '2H,3H,4H,TD,4S': [10],
#  '2H,3H,4H,TD,5S': [8],
#  '2H,3H,4H,TD,6S': [7],
#  '2H,3H,4H,TD,7S': [5],
#  '2H,3H,4H,TD,8S': [7],
#  '2H,3H,4H,TD,9S': [7],
#  '2H,3H,4H,TD,TS': [9],
#  '2H,3H,4H,TD,JS': [7],
#  '2H,3H,4H,TD,QS': [7],
#  '2H,3H,4H,TD,KS': [7],
#  '2H,3H,4H,TD,AS': [8],
#  '2H,3H,4H,TD,2C': [12],
#  '2H,3H,4H,TD,3C': [12],
#  '2H,3H,4H,TD,4C': [10],
#  '2H,3H,4H,TD,5C': [8],
#  '2H,3H,4H,TD,6C': [7],
#  '2H,3H,4H,TD,7C': [5],
#  '2H,3H,4H,TD,8C': [7],
#  '2H,3H,4H,TD,9C': [7],
#  '2H,3H,4H,TD,TC': [9],
#  '2H,3H,4H,TD,JC': [7],
#  '2H,3H,4H,TD,QC': [7],
#  '2H,3H,4H,TD,KC': [7],
#  '2H,3H,4H,TD,AC': [8],
#  '2H,3H,4H,JD,5H': [8],
#  '2H,3H,4H,JD,6H': [7],
#  '2H,3H,4H,JD,7H': [5],
#  '2H,3H,4H,JD,8H': [7],
#  '2H,3H,4H,JD,9H': [7],
#  '2H,3H,4H,JD,TH': [7],
#  '2H,3H,4H,JD,JH': [9],
#  '2H,3H,4H,JD,QH': [7],
#  '2H,3H,4H,JD,KH': [7],
#  '2H,3H,4H,JD,AH': [8],
#  '2H,3H,4H,JD,2D': [13],
#  '2H,3H,4H,JD,3D': [13],
#  '2H,3H,4H,JD,4D': [11],
#  '2H,3H,4H,JD,5D': [9],
#  '2H,3H,4H,JD,6D': [8],
#  '2H,3H,4H,JD,7D': [6],
#  '2H,3H,4H,JD,8D': [8],
#  '2H,3H,4H,JD,9D': [8],
#  '2H,3H,4H,JD,TD': [8],
#  '2H,3H,4H,JD,QD': [8],
#  '2H,3H,4H,JD,KD': [8],
#  '2H,3H,4H,JD,AD': [9],
#  '2H,3H,4H,JD,2S': [12],
#  '2H,3H,4H,JD,3S': [12],
#  '2H,3H,4H,JD,4S': [10],
#  '2H,3H,4H,JD,5S': [8],
#  '2H,3H,4H,JD,6S': [7],
#  '2H,3H,4H,JD,7S': [5],
#  '2H,3H,4H,JD,8S': [7],
#  '2H,3H,4H,JD,9S': [7],
#  '2H,3H,4H,JD,TS': [7],
#  '2H,3H,4H,JD,JS': [9],
#  '2H,3H,4H,JD,QS': [7],
#  '2H,3H,4H,JD,KS': [7],
#  '2H,3H,4H,JD,AS': [8],
#  '2H,3H,4H,JD,2C': [12],
#  '2H,3H,4H,JD,3C': [12],
#  '2H,3H,4H,JD,4C': [10],
#  '2H,3H,4H,JD,5C': [8],
#  '2H,3H,4H,JD,6C': [7],
#  '2H,3H,4H,JD,7C': [5],
#  '2H,3H,4H,JD,8C': [7],
#  '2H,3H,4H,JD,9C': [7],
#  '2H,3H,4H,JD,TC': [7],
#  '2H,3H,4H,JD,JC': [9],
#  '2H,3H,4H,JD,QC': [7],
#  '2H,3H,4H,JD,KC': [7],
#  '2H,3H,4H,JD,AC': [8],
#  '2H,3H,4H,QD,5H': [8],
#  '2H,3H,4H,QD,6H': [7],
#  '2H,3H,4H,QD,7H': [5],
#  '2H,3H,4H,QD,8H': [7],
#  '2H,3H,4H,QD,9H': [7],
#  '2H,3H,4H,QD,TH': [7],
#  '2H,3H,4H,QD,JH': [7],
#  '2H,3H,4H,QD,QH': [9],
#  '2H,3H,4H,QD,KH': [7],
#  '2H,3H,4H,QD,AH': [8],
#  '2H,3H,4H,QD,2D': [12],
#  '2H,3H,4H,QD,3D': [12],
#  '2H,3H,4H,QD,4D': [10],
#  '2H,3H,4H,QD,5D': [8],
#  '2H,3H,4H,QD,6D': [7],
#  '2H,3H,4H,QD,7D': [5],
#  '2H,3H,4H,QD,8D': [7],
#  '2H,3H,4H,QD,9D': [7],
#  '2H,3H,4H,QD,TD': [7],
#  '2H,3H,4H,QD,JD': [7],
#  '2H,3H,4H,QD,KD': [7],
#  '2H,3H,4H,QD,AD': [8],
#  '2H,3H,4H,QD,2S': [12],
#  '2H,3H,4H,QD,3S': [12],
#  '2H,3H,4H,QD,4S': [10],
#  '2H,3H,4H,QD,5S': [8],
#  '2H,3H,4H,QD,6S': [7],
#  '2H,3H,4H,QD,7S': [5],
#  '2H,3H,4H,QD,8S': [7],
#  '2H,3H,4H,QD,9S': [7],
#  '2H,3H,4H,QD,TS': [7],
#  '2H,3H,4H,QD,JS': [7],
#  '2H,3H,4H,QD,QS': [9],
#  '2H,3H,4H,QD,KS': [7],
#  '2H,3H,4H,QD,AS': [8],
#  '2H,3H,4H,QD,2C': [12],
#  '2H,3H,4H,QD,3C': [12],
#  '2H,3H,4H,QD,4C': [10],
#  '2H,3H,4H,QD,5C': [8],
#  '2H,3H,4H,QD,6C': [7],
#  ...}

# %%
points_df.head()
# Out:
#                 points
# hand
# 2H,3H,4H,5H,6H      14
# 2H,3H,4H,5H,7H      11
# 2H,3H,4H,5H,8H      13
# 2H,3H,4H,5H,9H      11
# 2H,3H,4H,5H,TH      13

# %%
# points_df.loc[(points_df["hand"] == "2H,3H,4H,6H")]
int(
    points_df.loc[
        (points_df["hand"] == "2H,3H,4H,5H") & (points_df["cut_card"] == "4C")
    ].points.values[0]
)
# Out:
# 16

# %%
class PersonalHand:
    def __init__(self, cards: tuple[str]):
        self.cards = cards
        self.cards_str = ",".join(cards)
        self.cards_set = set(cards)


class PlayedHand:
    def __init__(self, hand_cards: PersonalHand, cut_card: str):
        self.hand_cards = hand_cards
        self.cut_card = cut_card
        self.points: int = self._get_points(hand_cards, cut_card)

    def _get_points(self, hand_cards: PersonalHand, cut_card: str):
        # TODO
        # val = points_df.loc[
        #     (points_df["hand"] == hand_cards.cards_str)
        #     & (points_df["cut_card"] == cut_card)
        # ].points.values[0]

        hand = hand_cards.cards_str + "," + cut_card

        try:
            val = points_dict[hand]
        except KeyError:
            print(hand)
            raise

        return int(val[0])


class PossibleHand:
    def __init__(self, four_card_hand: PersonalHand, possible_crib_cards: tuple[str]):
        self.hand = four_card_hand
        self.possible_crib_cards = possible_crib_cards

        self.possible_played_hands: list[PlayedHand] = []
        self.possible_points: list[int] = []
        self.points_max: int = 0
        self.points_min: int = 29
        for cut_card in possible_crib_cards:
            played_hand = PlayedHand(four_card_hand, cut_card)
            self.possible_played_hands.append(played_hand)
            self.possible_points.append(played_hand.points)

            if played_hand.points > self.points_max:
                self.points_max = played_hand.points
            if played_hand.points < self.points_min:
                self.points_min = played_hand.points

        # self.possible_points = [hand.points for hand in self.possible_played_hands]

        self.points_ev = statistics.mean(self.possible_points)
        self.points_stdev = statistics.stdev(self.possible_points)
        self.points_median = statistics.median(self.possible_points)
        # self.points_max = max(self.possible_points)
        # self.points_min = min(self.possible_points)


class DealtHand:
    def __init__(self, cards: tuple[str]):
        self.cards = cards

        _copied_deck = deck.copy()

        for card in cards:
            _copied_deck.remove(card)

        self.possible_crib_cards = _copied_deck
        _possible_hands_tuples = list(combinations(cards, r=hand_size))
        self.possible_personal_hands = [
            PersonalHand(hand) for hand in _possible_hands_tuples
        ]

        self.possible_hands = [
            PossibleHand(hand, self.possible_crib_cards)
            for hand in self.possible_personal_hands
        ]

        self.ev_hand = max(self.possible_hands, key=lambda hand: hand.points_ev)
        self.max_hand = max(self.possible_hands, key=lambda hand: hand.points_max)
        self.median_hand = max(self.possible_hands, key=lambda hand: hand.points_median)

# %%
# example_hand = ("2H", "3H", "4H", "5H", "6H", "7H")
# example_hand_obj = DealtHand(example_hand)

# %%
# example_hand_2 = ("4H", "TH", "JH", "2D", "TD", "8S")
# example_hand_2_obj = DealtHand(example_hand_2)

# %%
# %%memray_flamegraph

from cProfile import Profile
from pstats import Stats, SortKey

with Profile() as pr:
    example_hand_3 = ("4H", "TH", "JH", "2D", "9D", "8S")
    example_hand_3_obj = DealtHand(example_hand_3)

    (Stats(pr).strip_dirs().sort_stats(SortKey.CUMULATIVE).print_stats())
# Out:
#          8790 function calls (8785 primitive calls) in 0.088 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       2/1    0.000    0.000    0.049    0.049 {method 'run' of '_contextvars.Context' objects}
#         1    0.000    0.000    0.049    0.049 asyncio.py:200(_handle_events)
#         1    0.000    0.000    0.049    0.049 zmqstream.py:584(_handle_events)
#         1    0.000    0.000    0.048    0.048 zmqstream.py:625(_handle_recv)
#         1    0.000    0.000    0.048    0.048 zmqstream.py:557(_run_callback)
#         1    0.000    0.000    0.048    0.048 iostream.py:157(_handle_event)
#       2/1    0.022    0.011    0.048    0.048 1572010496.py:61(__init__)
#     16/15    0.002    0.000    0.038    0.003 1572010496.py:33(__init__)
#   691/690    0.002    0.000    0.019    0.000 1572010496.py:9(__init__)
#       3/2    0.018    0.006    0.018    0.009 events.py:86(_run)
#        15    0.001    0.000    0.016    0.001 statistics.py:468(mean)
#       690    0.015    0.000    0.015    0.000 1572010496.py:14(_get_points)
#        15    0.001    0.000    0.011    0.001 statistics.py:154(_sum)
#        15    0.000    0.000    0.006    0.000 statistics.py:959(stdev)
#        15    0.005    0.000    0.006    0.000 statistics.py:208(_ss)
#        30    0.006    0.000    0.006    0.000 {built-in method _functools.reduce}
#        45    0.000    0.000    0.004    0.000 {built-in method builtins.sum}
#        60    0.000    0.000    0.003    0.000 fractions.py:627(reverse)
#         2    0.002    0.001    0.003    0.001 socket.py:626(send)
#        45    0.002    0.000    0.002    0.000 fractions.py:710(_add)
#         2    0.001    0.000    0.002    0.001 ipkernel.py:775(_clean_thread_parent_frames)
#        90    0.001    0.000    0.002    0.000 fractions.py:613(forward)
#         2    0.000    0.000    0.002    0.001 attrsettr.py:43(__getattr__)
#         1    0.001    0.001    0.001    0.001 threading.py:1533(enumerate)
#         1    0.000    0.000    0.001    0.001 zmqstream.py:664(_rebuild_io_state)
#         2    0.001    0.001    0.001    0.001 attrsettr.py:66(_get_attr_opt)
#      1380    0.001    0.000    0.001    0.000 statistics.py:287(_exact_ratio)
#         1    0.000    0.000    0.001    0.001 zmqstream.py:687(_update_handler)
#      1385    0.001    0.000    0.001    0.000 {method 'append' of 'list' objects}
#       234    0.000    0.000    0.001    0.000 {built-in method builtins.isinstance}
#       165    0.000    0.000    0.001    0.000 fractions.py:186(__new__)
#        30    0.000    0.000    0.001    0.000 statistics.py:203(<genexpr>)
#      1380    0.001    0.000    0.001    0.000 {method 'as_integer_ratio' of 'int' objects}
#         2    0.001    0.000    0.001    0.000 enum.py:1541(__and__)
#         1    0.000    0.000    0.000    0.000 {method 'execute' of 'sqlite3.Connection' objects}
#         4    0.000    0.000    0.000    0.000 enum.py:1531(__or__)
#       315    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x1056a4950}
#       120    0.000    0.000    0.000    0.000 <frozen abc>:117(__instancecheck__)
#        15    0.000    0.000    0.000    0.000 statistics.py:601(median)
#       120    0.000    0.000    0.000    0.000 {built-in method _abc._abc_instancecheck}
#       150    0.000    0.000    0.000    0.000 fractions.py:317(_from_coprime_ints)
#        45    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#        60    0.000    0.000    0.000    0.000 fractions.py:758(_div)
#        15    0.000    0.000    0.000    0.000 statistics.py:333(_convert)
#        15    0.000    0.000    0.000    0.000 {built-in method builtins.sorted}
#        30    0.000    0.000    0.000    0.000 statistics.py:239(<genexpr>)
#        15    0.000    0.000    0.000    0.000 statistics.py:425(_float_sqrt_of_frac)
#       285    0.000    0.000    0.000    0.000 {built-in method math.gcd}
#        30    0.000    0.000    0.000    0.000 fractions.py:742(_mul)
#         1    0.000    0.000    0.000    0.000 pstats.py:108(__init__)
#         1    0.000    0.000    0.000    0.000 pstats.py:118(init)
#       690    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 pstats.py:137(load_stats)
#         1    0.000    0.000    0.000    0.000 cProfile.py:52(create_stats)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#        15    0.000    0.000    0.000    0.000 statistics.py:413(_integer_sqrt_of_frac_rto)
#         1    0.000    0.000    0.000    0.000 selector_events.py:129(_read_from_self)
#        15    0.000    0.000    0.000    0.000 numbers.py:308(__float__)
#         1    0.000    0.000    0.000    0.000 selector_events.py:750(_process_events)
#         1    0.000    0.000    0.000    0.000 decorator.py:199(fix)
#        30    0.000    0.000    0.000    0.000 statistics.py:240(<genexpr>)
#         1    0.000    0.000    0.000    0.000 socket.py:778(recv_multipart)
#         1    0.000    0.000    0.000    0.000 base_events.py:1893(_add_callback)
#         9    0.000    0.000    0.000    0.000 enum.py:713(__call__)
#        15    0.000    0.000    0.000    0.000 {built-in method math.isqrt}
#         1    0.000    0.000    0.000    0.000 queues.py:186(put)
#         1    0.000    0.000    0.000    0.000 zmqstream.py:543(sending)
#        15    0.000    0.000    0.000    0.000 fractions.py:726(_sub)
#         1    0.000    0.000    0.000    0.000 inspect.py:3254(bind)
#         1    0.000    0.000    0.000    0.000 queues.py:209(put_nowait)
#         2    0.000    0.000    0.000    0.000 {method 'recv' of '_socket.socket' objects}
#         1    0.000    0.000    0.000    0.000 inspect.py:3119(_bind)
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#         3    0.000    0.000    0.000    0.000 typing.py:378(inner)
#         9    0.000    0.000    0.000    0.000 enum.py:1116(__new__)
#        15    0.000    0.000    0.000    0.000 1572010496.py:2(__init__)
#         1    0.000    0.000    0.000    0.000 base_events.py:732(time)
#        30    0.000    0.000    0.000    0.000 statistics.py:256(_coerce)
#         1    0.000    0.000    0.000    0.000 queue.py:97(empty)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1390(_handle_fromlist)
#         1    0.000    0.000    0.000    0.000 concurrent.py:182(future_set_result_unless_cancelled)
#         4    0.000    0.000    0.000    0.000 traitlets.py:676(__get__)
#         1    0.000    0.000    0.000    0.000 threading.py:311(_acquire_restore)
#         2    0.000    0.000    0.000    0.000 {method 'set_result' of '_asyncio.Future' objects}
#         2    0.000    0.000    0.000    0.000 typing.py:1239(__hash__)
#         1    0.000    0.000    0.000    0.000 {built-in method time.monotonic}
#        30    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#         7    0.000    0.000    0.000    0.000 threading.py:1196(ident)
#        20    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 queues.py:322(_consume_expired)
#        30    0.000    0.000    0.000    0.000 {method 'bit_length' of 'int' objects}
#        30    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#         1    0.000    0.000    0.000    0.000 inspect.py:2935(apply_defaults)
#         1    0.000    0.000    0.000    0.000 base_events.py:783(call_soon)
#        45    0.000    0.000    0.000    0.000 fractions.py:401(denominator)
#         1    0.000    0.000    0.000    0.000 inspect.py:2882(args)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         1    0.000    0.000    0.000    0.000 iostream.py:216(_check_mp_mode)
#         4    0.000    0.000    0.000    0.000 traitlets.py:629(get)
#         1    0.000    0.000    0.000    0.000 base_events.py:812(_call_soon)
#         1    0.000    0.000    0.000    0.000 threading.py:627(clear)
#         1    0.000    0.000    0.000    0.000 queues.py:317(__put_internal)
#        30    0.000    0.000    0.000    0.000 fractions.py:397(numerator)
#         1    0.000    0.000    0.000    0.000 iostream.py:213(_is_master_process)
#        15    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#        15    0.000    0.000    0.000    0.000 1572010496.py:81(<lambda>)
#         2    0.000    0.000    0.000    0.000 threading.py:302(__exit__)
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#         6    0.000    0.000    0.000    0.000 {method 'remove' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 queue.py:209(_qsize)
#         6    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 inspect.py:2905(kwargs)
#         2    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         5    0.000    0.000    0.000    0.000 {method 'popleft' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         3    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 threading.py:299(__enter__)
#        15    0.000    0.000    0.000    0.000 1572010496.py:87(<lambda>)
#         4    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#        15    0.000    0.000    0.000    0.000 1572010496.py:84(<lambda>)
#         1    0.000    0.000    0.000    0.000 queues.py:312(_put)
#         1    0.000    0.000    0.000    0.000 {method 'values' of 'mappingproxy' objects}
#         2    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#         3    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 unix_events.py:81(_process_self_data)
#        10    0.000    0.000    0.000    0.000 inspect.py:2794(kind)
#         2    0.000    0.000    0.000    0.000 zmqstream.py:539(receiving)
#         1    0.000    0.000    0.000    0.000 selectors.py:275(_key_from_fd)
#         1    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#         3    0.000    0.000    0.000    0.000 {method 'items' of 'mappingproxy' objects}
#         9    0.000    0.000    0.000    0.000 typing.py:2132(cast)
#         1    0.000    0.000    0.000    0.000 {method 'copy' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#         1    0.000    0.000    0.000    0.000 events.py:36(__init__)
#         1    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         1    0.000    0.000    0.000    0.000 queues.py:177(empty)
#         1    0.000    0.000    0.000    0.000 queues.py:309(_get)
#         4    0.000    0.000    0.000    0.000 inspect.py:2782(name)
#         1    0.000    0.000    0.000    0.000 {method 'done' of '_asyncio.Future' objects}
#         1    0.000    0.000    0.000    0.000 iostream.py:255(closed)
#         1    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 locks.py:224(clear)
#         4    0.000    0.000    0.000    0.000 inspect.py:3075(parameters)
#         2    0.000    0.000    0.000    0.000 base_events.py:2003(get_debug)
#         1    0.000    0.000    0.000    0.000 inspect.py:2874(__init__)
#         1    0.000    0.000    0.000    0.000 {method 'cancelled' of '_asyncio.Future' objects}
#         1    0.000    0.000    0.000    0.000 base_events.py:538(_check_closed)

# %%
print(f"{example_hand_3_obj.max_hand.hand.cards_str=}")
print(f"{example_hand_3_obj.ev_hand.hand.cards_str=}")
print(f"{example_hand_3_obj.median_hand.hand.cards_str=}")
# Out:
# example_hand_3_obj.best_possible_hand_by_max.hand.cards_str='TH,JH,9D,8S'
# example_hand_3_obj.best_possible_hand_by_ev.hand.cards_str='TH,JH,9D,8S'
# example_hand_3_obj.best_possible_hand_by_median.hand.cards_str='TH,JH,9D,8S'

# %%
df = pd.DataFrame(
    columns=[
        "dealt_hand",
        "max_hand",
        "max_hand_ev_points",
        "max_hand_max_points",
        "max_hand_median_points",
        "max_hand_stdev_points",
        "median_hand",
        "median_hand_ev_points",
        "median_hand_max_points",
        "median_hand_median_points",
        "median_hand_stdev_points",
        "ev_hand",
        "ev_hand_ev_points",
        "ev_hand_max_points",
        "ev_hand_median_points",
        "ev_hand_stdev_points",
    ]
)

# %%
from tqdm import tqdm

for starting_hand in tqdm(starting_hand_list):
    staring_dealt_hand: DealtHand = DealtHand(starting_hand)

    row = [
        ",".join(staring_dealt_hand.cards),
    ]

    best_hands = [
        staring_dealt_hand.max_hand,
        staring_dealt_hand.median_hand,
        staring_dealt_hand.ev_hand,
    ]

    for best_hand in best_hands:
        row.append(best_hand.hand.cards_str)
        row.append(best_hand.points_ev)
        row.append(best_hand.points_max)
        row.append(best_hand.points_median)
        row.append(best_hand.points_stdev)

    # df = pd.concat([pd.DataFrame([[1,2]], columns=df.columns), df], ignore_index=True)
    df = pd.concat([pd.DataFrame([row], columns=df.columns), df], ignore_index=True)
# Out:
#   0%|          | 0/20358520 [00:00<?, ?it/s]/var/folders/jb/2g0yf8sx4cs6_kt_mtlb1z3m0000gn/T/ipykernel_48213/1575519737.py:24: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([pd.DataFrame([row], columns=df.columns), df], ignore_index=True)
#   1%|          | 112299/20358520 [07:54<40:16:00, 139.67it/s]Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x106da33e0>>
# Traceback (most recent call last):
#   File "/Users/ianpaul/code/cribbage-hand-statistics/venv/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 775, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
#
# KeyboardInterrupt:
#   1%|          | 113022/20358520 [08:00<48:01:38, 117.09it/s]
