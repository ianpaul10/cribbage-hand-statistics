# %%
import pandas as pd
from plotly_app.points_by_hand import PlayedHand, DealtHand

# %%
df = pd.read_parquet("csv_outputs/crib_hands_sorted.parquet")

# %%
hand = "2C,2H,3H,4H,7D,QC"

hand_obj = DealtHand(hand, df)
# Out:
#            points
# count  690.000000
# mean     5.791304
# std      3.485809
# min      0.000000
# 25%      4.000000
# 50%      5.000000
# 75%      8.000000
# max     18.000000
#                            points cut_card  sorted_hand
# sorted_hand_plus_cut_card
# 2C,2H,3H,4H,5H                 10       5H  2C,2H,3H,4H
# 2C,2H,3H,4H,6H                 12       6H  2C,2H,3H,4H
# 2C,2H,3H,4H,7H                 10       7H  2C,2H,3H,4H
# 2C,2H,3H,4H,8H                 12       8H  2C,2H,3H,4H
# 2C,2H,3H,4H,9H                 12       9H  2C,2H,3H,4H
# sorted_hand  2C,2D,2H,3H  2C,2D,2H,4H  ...  3H,4H,7D,KS  3H,4H,7D,QC
# count           3.000000     2.000000  ...          1.0     7.000000
# mean           11.000000     9.000000  ...          0.0     0.857143
# std             4.582576     4.242641  ...          NaN     1.069045
# min             6.000000     6.000000  ...          0.0     0.000000
# 25%             9.000000     7.500000  ...          0.0     0.000000
# 50%            12.000000     9.000000  ...          0.0     0.000000
# 75%            13.500000    10.500000  ...          0.0     2.000000
# max            15.000000    12.000000  ...          0.0     2.000000
#
# [8 rows x 405 columns]
# sorted_hand  2C,2D,2H,3H  2C,2D,2H,4H  ...  3H,4H,7D,KS  3H,4H,7D,QC
# cut_card                               ...
# 4H                  15.0          NaN  ...          NaN          NaN
# 4S                   NaN          NaN  ...          NaN          NaN
# 5C                   NaN          NaN  ...          NaN          NaN
# 5D                   NaN          NaN  ...          NaN          NaN
# 5H                   NaN          NaN  ...          NaN          NaN
#
# [5 rows x 405 columns]
# Index(['2C,2D,2H,3H', '2C,2D,2H,4H', '2C,2D,2H,7D', '2C,2D,3H,4H',
#        '2C,2D,3H,7D', '2C,2D,4H,7D', '2C,2H,2S,3H', '2C,2H,2S,4H',
#        '2C,2H,2S,7D', '2C,2H,3C,3H',
#        ...
#        '3H,4H,7D,AS', '3H,4H,7D,JC', '3H,4H,7D,JD', '3H,4H,7D,JH',
#        '3H,4H,7D,JS', '3H,4H,7D,KC', '3H,4H,7D,KD', '3H,4H,7D,KH',
#        '3H,4H,7D,KS', '3H,4H,7D,QC'],
#       dtype='object', name='sorted_hand', length=405)

# %%
hand_obj.pivoted_df.columns.tolist()
# Out:
# ['2C,2D,2H,3H',
#  '2C,2D,2H,4H',
#  '2C,2D,2H,7D',
#  '2C,2D,3H,4H',
#  '2C,2D,3H,7D',
#  '2C,2D,4H,7D',
#  '2C,2H,2S,3H',
#  '2C,2H,2S,4H',
#  '2C,2H,2S,7D',
#  '2C,2H,3C,3H',
#  '2C,2H,3C,4H',
#  '2C,2H,3C,7D',
#  '2C,2H,3D,3H',
#  '2C,2H,3D,4H',
#  '2C,2H,3D,7D',
#  '2C,2H,3H,3S',
#  '2C,2H,3H,4C',
#  '2C,2H,3H,4D',
#  '2C,2H,3H,4H',
#  '2C,2H,3H,4S',
#  '2C,2H,3H,5C',
#  '2C,2H,3H,5D',
#  '2C,2H,3H,5H',
#  '2C,2H,3H,5S',
#  '2C,2H,3H,6C',
#  '2C,2H,3H,6D',
#  '2C,2H,3H,6H',
#  '2C,2H,3H,6S',
#  '2C,2H,3H,7C',
#  '2C,2H,3H,7D',
#  '2C,2H,3H,7H',
#  '2C,2H,3H,7S',
#  '2C,2H,3H,8C',
#  '2C,2H,3H,8D',
#  '2C,2H,3H,8H',
#  '2C,2H,3H,8S',
#  '2C,2H,3H,9C',
#  '2C,2H,3H,9D',
#  '2C,2H,3H,9H',
#  '2C,2H,3H,9S',
#  '2C,2H,3H,AC',
#  '2C,2H,3H,AD',
#  '2C,2H,3H,AH',
#  '2C,2H,3H,AS',
#  '2C,2H,3H,JC',
#  '2C,2H,3H,JD',
#  '2C,2H,3H,JH',
#  '2C,2H,3H,JS',
#  '2C,2H,3H,KC',
#  '2C,2H,3H,KD',
#  '2C,2H,3H,KH',
#  '2C,2H,3H,KS',
#  '2C,2H,3H,QC',
#  '2C,2H,3S,4H',
#  '2C,2H,3S,7D',
#  '2C,2H,4C,4H',
#  '2C,2H,4C,7D',
#  '2C,2H,4D,4H',
#  '2C,2H,4D,7D',
#  '2C,2H,4H,4S',
#  '2C,2H,4H,5C',
#  '2C,2H,4H,5D',
#  '2C,2H,4H,5H',
#  '2C,2H,4H,5S',
#  '2C,2H,4H,6C',
#  '2C,2H,4H,6D',
#  '2C,2H,4H,6H',
#  '2C,2H,4H,6S',
#  '2C,2H,4H,7C',
#  '2C,2H,4H,7D',
#  '2C,2H,4H,7H',
#  '2C,2H,4H,7S',
#  '2C,2H,4H,8C',
#  '2C,2H,4H,8D',
#  '2C,2H,4H,8H',
#  '2C,2H,4H,8S',
#  '2C,2H,4H,9C',
#  '2C,2H,4H,9D',
#  '2C,2H,4H,9H',
#  '2C,2H,4H,9S',
#  '2C,2H,4H,AC',
#  '2C,2H,4H,AD',
#  '2C,2H,4H,AH',
#  '2C,2H,4H,AS',
#  '2C,2H,4H,JC',
#  '2C,2H,4H,JD',
#  '2C,2H,4H,JH',
#  '2C,2H,4H,JS',
#  '2C,2H,4H,KC',
#  '2C,2H,4H,KD',
#  '2C,2H,4H,KH',
#  '2C,2H,4H,KS',
#  '2C,2H,4H,QC',
#  '2C,2H,4S,7D',
#  '2C,2H,5C,7D',
#  '2C,2H,5D,7D',
#  '2C,2H,5H,7D',
#  '2C,2H,5S,7D',
#  '2C,2H,6C,7D',
#  '2C,2H,6D,7D',
#  '2C,2H,6H,7D',
#  '2C,2H,6S,7D',
#  '2C,2H,7C,7D',
#  '2C,2H,7D,7H',
#  '2C,2H,7D,7S',
#  '2C,2H,7D,8C',
#  '2C,2H,7D,8D',
#  '2C,2H,7D,8H',
#  '2C,2H,7D,8S',
#  '2C,2H,7D,9C',
#  '2C,2H,7D,9D',
#  '2C,2H,7D,9H',
#  '2C,2H,7D,9S',
#  '2C,2H,7D,AC',
#  '2C,2H,7D,AD',
#  '2C,2H,7D,AH',
#  '2C,2H,7D,AS',
#  '2C,2H,7D,JC',
#  '2C,2H,7D,JD',
#  '2C,2H,7D,JH',
#  '2C,2H,7D,JS',
#  '2C,2H,7D,KC',
#  '2C,2H,7D,KD',
#  '2C,2H,7D,KH',
#  '2C,2H,7D,KS',
#  '2C,2H,7D,QC',
#  '2C,2S,3H,4H',
#  '2C,2S,3H,7D',
#  '2C,2S,4H,7D',
#  '2C,3C,3H,4H',
#  '2C,3C,3H,7D',
#  '2C,3C,4H,7D',
#  '2C,3D,3H,4H',
#  '2C,3D,3H,7D',
#  '2C,3D,4H,7D',
#  '2C,3H,3S,4H',
#  '2C,3H,3S,7D',
#  '2C,3H,4C,4H',
#  '2C,3H,4C,7D',
#  '2C,3H,4D,4H',
#  '2C,3H,4D,7D',
#  '2C,3H,4H,4S',
#  '2C,3H,4H,5C',
#  '2C,3H,4H,5D',
#  '2C,3H,4H,5H',
#  '2C,3H,4H,5S',
#  '2C,3H,4H,6C',
#  '2C,3H,4H,6D',
#  '2C,3H,4H,6H',
#  '2C,3H,4H,6S',
#  '2C,3H,4H,7C',
#  '2C,3H,4H,7D',
#  '2C,3H,4H,7H',
#  '2C,3H,4H,7S',
#  '2C,3H,4H,8C',
#  '2C,3H,4H,8D',
#  '2C,3H,4H,8H',
#  '2C,3H,4H,8S',
#  '2C,3H,4H,9C',
#  '2C,3H,4H,9D',
#  '2C,3H,4H,9H',
#  '2C,3H,4H,9S',
#  '2C,3H,4H,AC',
#  '2C,3H,4H,AD',
#  '2C,3H,4H,AH',
#  '2C,3H,4H,AS',
#  '2C,3H,4H,JC',
#  '2C,3H,4H,JD',
#  '2C,3H,4H,JH',
#  '2C,3H,4H,JS',
#  '2C,3H,4H,KC',
#  '2C,3H,4H,KD',
#  '2C,3H,4H,KH',
#  '2C,3H,4H,KS',
#  '2C,3H,4H,QC',
#  '2C,3H,4S,7D',
#  '2C,3H,5C,7D',
#  '2C,3H,5D,7D',
#  '2C,3H,5H,7D',
#  '2C,3H,5S,7D',
#  '2C,3H,6C,7D',
#  '2C,3H,6D,7D',
#  '2C,3H,6H,7D',
#  '2C,3H,6S,7D',
#  '2C,3H,7C,7D',
#  '2C,3H,7D,7H',
#  '2C,3H,7D,7S',
#  '2C,3H,7D,8C',
#  '2C,3H,7D,8D',
#  '2C,3H,7D,8H',
#  '2C,3H,7D,8S',
#  '2C,3H,7D,9C',
#  '2C,3H,7D,9D',
#  '2C,3H,7D,9H',
#  '2C,3H,7D,9S',
#  '2C,3H,7D,AC',
#  '2C,3H,7D,AD',
#  '2C,3H,7D,AH',
#  '2C,3H,7D,AS',
#  '2C,3H,7D,JC',
#  '2C,3H,7D,JD',
#  '2C,3H,7D,JH',
#  '2C,3H,7D,JS',
#  '2C,3H,7D,KC',
#  '2C,3H,7D,KD',
#  '2C,3H,7D,KH',
#  '2C,3H,7D,KS',
#  '2C,3H,7D,QC',
#  '2C,3S,4H,7D',
#  '2C,4C,4H,7D',
#  '2C,4D,4H,7D',
#  '2C,4H,4S,7D',
#  '2C,4H,5C,7D',
#  '2C,4H,5D,7D',
#  '2C,4H,5H,7D',
#  '2C,4H,5S,7D',
#  '2C,4H,6C,7D',
#  '2C,4H,6D,7D',
#  '2C,4H,6H,7D',
#  '2C,4H,6S,7D',
#  '2C,4H,7C,7D',
#  '2C,4H,7D,7H',
#  '2C,4H,7D,7S',
#  '2C,4H,7D,8C',
#  '2C,4H,7D,8D',
#  '2C,4H,7D,8H',
#  '2C,4H,7D,8S',
#  '2C,4H,7D,9C',
#  '2C,4H,7D,9D',
#  '2C,4H,7D,9H',
#  '2C,4H,7D,9S',
#  '2C,4H,7D,AC',
#  '2C,4H,7D,AD',
#  '2C,4H,7D,AH',
#  '2C,4H,7D,AS',
#  '2C,4H,7D,JC',
#  '2C,4H,7D,JD',
#  '2C,4H,7D,JH',
#  '2C,4H,7D,JS',
#  '2C,4H,7D,KC',
#  '2C,4H,7D,KD',
#  '2C,4H,7D,KH',
#  '2C,4H,7D,KS',
#  '2C,4H,7D,QC',
#  '2D,2H,3H,4H',
#  '2D,2H,3H,7D',
#  '2D,2H,4H,7D',
#  '2D,3H,4H,7D',
#  '2H,2S,3H,4H',
#  '2H,2S,3H,7D',
#  '2H,2S,4H,7D',
#  '2H,3C,3H,4H',
#  '2H,3C,3H,7D',
#  '2H,3C,4H,7D',
#  '2H,3D,3H,4H',
#  '2H,3D,3H,7D',
#  '2H,3D,4H,7D',
#  '2H,3H,3S,4H',
#  '2H,3H,3S,7D',
#  '2H,3H,4C,4H',
#  '2H,3H,4C,7D',
#  '2H,3H,4D,4H',
#  '2H,3H,4D,7D',
#  '2H,3H,4H,4S',
#  '2H,3H,4H,5C',
#  '2H,3H,4H,5D',
#  '2H,3H,4H,5H',
#  '2H,3H,4H,5S',
#  '2H,3H,4H,6C',
#  '2H,3H,4H,6D',
#  '2H,3H,4H,6H',
#  '2H,3H,4H,6S',
#  '2H,3H,4H,7C',
#  '2H,3H,4H,7D',
#  '2H,3H,4H,7H',
#  '2H,3H,4H,7S',
#  '2H,3H,4H,8C',
#  '2H,3H,4H,8D',
#  '2H,3H,4H,8H',
#  '2H,3H,4H,8S',
#  '2H,3H,4H,9C',
#  '2H,3H,4H,9D',
#  '2H,3H,4H,9H',
#  '2H,3H,4H,9S',
#  '2H,3H,4H,AC',
#  '2H,3H,4H,AD',
#  '2H,3H,4H,AH',
#  '2H,3H,4H,AS',
#  '2H,3H,4H,JC',
#  '2H,3H,4H,JD',
#  '2H,3H,4H,JH',
#  '2H,3H,4H,JS',
#  '2H,3H,4H,KC',
#  '2H,3H,4H,KD',
#  '2H,3H,4H,KH',
#  '2H,3H,4H,KS',
#  '2H,3H,4H,QC',
#  '2H,3H,4S,7D',
#  '2H,3H,5C,7D',
#  '2H,3H,5D,7D',
#  '2H,3H,5H,7D',
#  '2H,3H,5S,7D',
#  '2H,3H,6C,7D',
#  '2H,3H,6D,7D',
#  '2H,3H,6H,7D',
#  '2H,3H,6S,7D',
#  '2H,3H,7C,7D',
#  '2H,3H,7D,7H',
#  '2H,3H,7D,7S',
#  '2H,3H,7D,8C',
#  '2H,3H,7D,8D',
#  '2H,3H,7D,8H',
#  '2H,3H,7D,8S',
#  '2H,3H,7D,9C',
#  '2H,3H,7D,9D',
#  '2H,3H,7D,9H',
#  '2H,3H,7D,9S',
#  '2H,3H,7D,AC',
#  '2H,3H,7D,AD',
#  '2H,3H,7D,AH',
#  '2H,3H,7D,AS',
#  '2H,3H,7D,JC',
#  '2H,3H,7D,JD',
#  '2H,3H,7D,JH',
#  '2H,3H,7D,JS',
#  '2H,3H,7D,KC',
#  '2H,3H,7D,KD',
#  '2H,3H,7D,KH',
#  '2H,3H,7D,KS',
#  '2H,3H,7D,QC',
#  '2H,3S,4H,7D',
#  '2H,4C,4H,7D',
#  '2H,4D,4H,7D',
#  '2H,4H,4S,7D',
#  '2H,4H,5C,7D',
#  '2H,4H,5D,7D',
#  '2H,4H,5H,7D',
#  '2H,4H,5S,7D',
#  '2H,4H,6C,7D',
#  '2H,4H,6D,7D',
#  '2H,4H,6H,7D',
#  '2H,4H,6S,7D',
#  '2H,4H,7C,7D',
#  '2H,4H,7D,7H',
#  '2H,4H,7D,7S',
#  '2H,4H,7D,8C',
#  '2H,4H,7D,8D',
#  '2H,4H,7D,8H',
#  '2H,4H,7D,8S',
#  '2H,4H,7D,9C',
#  '2H,4H,7D,9D',
#  '2H,4H,7D,9H',
#  '2H,4H,7D,9S',
#  '2H,4H,7D,AC',
#  '2H,4H,7D,AD',
#  '2H,4H,7D,AH',
#  '2H,4H,7D,AS',
#  '2H,4H,7D,JC',
#  '2H,4H,7D,JD',
#  '2H,4H,7D,JH',
#  '2H,4H,7D,JS',
#  '2H,4H,7D,KC',
#  '2H,4H,7D,KD',
#  '2H,4H,7D,KH',
#  '2H,4H,7D,KS',
#  '2H,4H,7D,QC',
#  '2S,3H,4H,7D',
#  '3C,3H,4H,7D',
#  '3D,3H,4H,7D',
#  '3H,3S,4H,7D',
#  '3H,4C,4H,7D',
#  '3H,4D,4H,7D',
#  '3H,4H,4S,7D',
#  '3H,4H,5C,7D',
#  '3H,4H,5D,7D',
#  '3H,4H,5H,7D',
#  '3H,4H,5S,7D',
#  '3H,4H,6C,7D',
#  '3H,4H,6D,7D',
#  '3H,4H,6H,7D',
#  '3H,4H,6S,7D',
#  '3H,4H,7C,7D',
#  '3H,4H,7D,7H',
#  '3H,4H,7D,7S',
#  '3H,4H,7D,8C',
#  '3H,4H,7D,8D',
#  '3H,4H,7D,8H',
#  '3H,4H,7D,8S',
#  '3H,4H,7D,9C',
#  '3H,4H,7D,9D',
#  '3H,4H,7D,9H',
#  '3H,4H,7D,9S',
#  '3H,4H,7D,AC',
#  '3H,4H,7D,AD',
#  '3H,4H,7D,AH',
#  '3H,4H,7D,AS',
#  '3H,4H,7D,JC',
#  '3H,4H,7D,JD',
#  '3H,4H,7D,JH',
#  '3H,4H,7D,JS',
#  '3H,4H,7D,KC',
#  '3H,4H,7D,KD',
#  '3H,4H,7D,KH',
#  '3H,4H,7D,KS',
#  '3H,4H,7D,QC']
